# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from dotenv import load_dotenv
import os

load_dotenv()
KEY = os.getenv("API_KEY")
CRN = os.getenv("CRN")

service = QiskitRuntimeService(channel="ibm_quantum_platform", token=KEY, instance=CRN)
# Out:
# qiskit_runtime_service._discover_account:WARNING:2025-12-08 16:41:17,824: Loading account with the given token. A saved account will not be used.

# %%
service.save_account(channel="ibm_quantum_platform", token=KEY, instance=CRN)

# %%
backend = service.backend("ibm_fez")
